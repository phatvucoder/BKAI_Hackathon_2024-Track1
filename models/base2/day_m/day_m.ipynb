# %%
# !pip install -q git+https://github.com/phatvucoder/pdatakit.git
# !pip -q install gdown
# !sudo apt-get update & sudo apt-get install unzip
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1581 B]
# Get:2 https://packages.cloud.google.com/apt gcsfuse-focal InRelease [1227 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1172 kB]
# Get:4 https://packages.cloud.google.com/apt cloud-sdk InRelease [1618 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://packages.cloud.google.com/apt google-fast-socket InRelease [1071 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://packages.cloud.google.com/apt gcsfuse-focal/main amd64 Packages [28.6 kB]
# Get:10 https://packages.cloud.google.com/apt cloud-sdk/main all Packages [1582 kB]
# Get:11 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [3428 kB]
# Reading package lists... Done 85%]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2452 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Building dependency tree... Done%] [12 Packages 34.5 kB/2452 kB 1%]
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# 42% [Waiting for headers] [12 Packages 214 kB/2452 kB 9%]0 upgraded, 0 newly installed, 0 to remove and 68 not upgraded.

# %%
# !gdown 1D1YYc2nxpifm9tLqH8v9jxMvZtjtwFuZ
# !unzip -q obj_bkgr -d dataset
# !rm -rf ./dataset/__MACOSX
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1D1YYc2nxpifm9tLqH8v9jxMvZtjtwFuZ
# From (redirected): https://drive.google.com/uc?id=1D1YYc2nxpifm9tLqH8v9jxMvZtjtwFuZ&confirm=t&uuid=a2ee17fd-b68d-4166-8c11-994ebff44760
# To: /kaggle/working/obj_bkgr.zip
# 100%|███████████████████████████████████████| 1.54G/1.54G [00:09<00:00, 157MB/s]

# %%
from pdatakit.pod.data_processor import DataProcessor
from pdatakit.pod.data_formatter import FormatType
import shutil

# %%
# shutil.copytree('/kaggle/input/bkai2024', '/kaggle/working/bkai2024')

# %%
processor = DataProcessor(
    data_root='./dataset/daytime',
    image_extension='jpg',
    label_extension='txt',
    train_size=0.7,
    val_size=0.2,
    test_size=0.1,
    random_state=42
)

# %%
for i in range(4, 8):
    processor.process_labels(i, i-4)
# Out:
# Replacing '4' with '0' in label files...
# Label replacement completed. Processed 6891 files, modified 0 files.
# Replacing '5' with '1' in label files...
# Label replacement completed. Processed 6891 files, modified 0 files.
# Replacing '6' with '2' in label files...
# Label replacement completed. Processed 6891 files, modified 0 files.
# Replacing '7' with '3' in label files...
# Label replacement completed. Processed 6891 files, modified 0 files.

# %%
processor.split_data()
# Out:
# Data splitting completed.
# Training samples: 4831
# Validation samples: 1388
# Testing samples: 672

# %%
processor.visualize_distributions()

# %%
class_mapping = {
    0: 'motorbike',
    1: 'car',
    2: 'bus',
    3: 'truck'
}

# Format the data into YOLO New format and save to 'formatted_data' directory
processor.format_data(
    output_dir='./yolo_data',
    format_type=FormatType.YOLO_NEW,
    class_mapping=class_mapping
)
# Out:
# Creating YOLO New format...
# Created data.yaml at yolo_data/data.yaml
# YOLO New format created successfully.
# Data formatted into yolo_new format and saved to ./yolo_data.

# %%
processor.summary()
# Out:
# ===== Data Manager Summary =====
# Data Root: ./dataset/daytime
# Image Extension: jpg
# Label Extension: txt
# Total Images: 6891
# Total Labels: 6891
# Training Samples: 4831
# Validation Samples: 1388
# Testing Samples: 672
# Class Distribution in Training Set:
#   0: 45111
#   1: 12148
#   2: 2855
#   3: 8299
# Class Distribution in Validation Set:
#   0: 13941
#   1: 3697
#   2: 784
#   3: 2396
# Class Distribution in Testing Set:
#   0: 6554
#   1: 1709
#   2: 396
#   3: 1178
# =================================

# %%
import numpy as np

class_distribution = processor.splitter.get_class_distribution()
total_samples_per_class = np.sum(class_distribution, axis=0)
total_samples = np.sum(total_samples_per_class)
class_weights = total_samples / total_samples_per_class
class_weights
# Out:
# array([ 1.51004481,  5.64361399, 24.55216853,  8.34397372])

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
# !yolo train data=/kaggle/working/yolo_data/data.yaml model=yolo11m.pt lr0=0.0001 epochs=100 batch=32 device=0,1 cache=ram
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt'...
# 100%|██████████████████████████████████████| 38.8M/38.8M [00:00<00:00, 58.5MB/s]
# Ultralytics 8.3.36 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11m.pt, data=/kaggle/working/yolo_data/data.yaml, epochs=100, time=None, patience=100, batch=32, imgsz=640, save=True, save_period=-1, cache=ram, device=(0, 1), workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.0001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 3.72MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1414108  ultralytics.nn.modules.head.Detect           [4, [256, 512, 512]]
# YOLO11m summary: 409 layers, 20,056,092 parameters, 20,056,076 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# DDP: debug command /opt/conda/bin/python3.10 -m torch.distributed.run --nproc_per_node 2 --master_port 50789 /root/.config/Ultralytics/DDP/_temp_99e0ju9g134380530035264.py
# Ultralytics 8.3.36 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 16.1MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/working/yolo_data/train/labels... 4831 images, 0 backgro
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_01_00317.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_01_00857.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_01_00961.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00316.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00565.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00579.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00951.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00022.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00110.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00328.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00346.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00355.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00374.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00491.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00514.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00536.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00633.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00709.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00881.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00915.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00947.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_06_00803.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_10_00135.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_10_00136.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/yolo_data/train/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (3.1GB RAM): 100%|██████████| 4831/4831 [00:10<00:00, 456.
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/yolo_data/val/labels... 1388 images, 0 backgrounds
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00014.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00016.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00018.jpg: 1 duplicate labels removed
# val: WARNING ⚠️
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.965      0.965      0.977      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      9.01G       0.22     0.1514     0.7715        733        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.965      0.959      0.979      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      9.14G      0.219     0.1504     0.7722        784        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.963      0.962      0.979      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      8.97G     0.2213     0.1508     0.7717        812        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.961      0.978      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      9.09G     0.2175     0.1477     0.7718        646        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.967      0.964      0.979      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      8.95G     0.2129     0.1461     0.7718        821        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.967      0.964      0.979      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      9.06G     0.2141     0.1461     0.7719        533        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.961      0.978      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      9.15G     0.2135     0.1459     0.7723       1142        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.967      0.965      0.978      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      8.92G     0.2058     0.1419     0.7706        683        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.972       0.96      0.978      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      9.15G     0.2127     0.1439     0.7715        896        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.967      0.964      0.978      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      9.07G     0.2105     0.1429      0.771        744        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.961      0.978      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      9.14G     0.2098     0.1427      0.771        798        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.961      0.979      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      9.16G     0.2062     0.1404     0.7704        784        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.965      0.979      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      9.08G      0.207       0.14     0.7709        738        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.963      0.979      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      9.09G     0.2067     0.1399     0.7714        782        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.964      0.979      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      9.19G      0.203     0.1374     0.7708        675        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.964      0.978      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      9.18G     0.2026     0.1379     0.7705        829        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.969      0.965       0.98      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      9.18G     0.2014     0.1359     0.7705        897        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.969      0.965      0.979      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      9.14G     0.2024     0.1362       0.77        626        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.965      0.968      0.978      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      9.16G     0.1975     0.1337     0.7718        496        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.964      0.979      0.928
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      8.71G     0.4106     0.2346      0.793        235        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.969      0.963      0.979      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      8.67G     0.3959     0.2259     0.7903        233        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.969      0.962      0.979      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      8.73G     0.3909     0.2243     0.7862        243        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.962      0.966      0.979       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      8.69G     0.3819     0.2193     0.7856        163        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.967      0.969      0.979      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      8.69G     0.3815     0.2169     0.7862        182        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.972      0.966       0.98      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      8.63G     0.3775      0.211     0.7855        229        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.976      0.963      0.979      0.932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      8.76G     0.3729     0.2086     0.7842        190        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.974      0.964       0.98      0.934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      8.75G      0.369       0.21     0.7844        291        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.971      0.965       0.98      0.934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      8.74G     0.3677     0.2046     0.7822        207        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.971      0.965       0.98      0.935
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      8.66G     0.3638     0.2023     0.7842        252        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.973      0.966      0.981      0.935
#
# 100 epochs completed in 3.344 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 40.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 40.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.36 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 303 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.972      0.966      0.981      0.935
#              motorbike       1298      13936      0.996      0.987      0.994      0.913
#                    car       1051       3695      0.986      0.977      0.988      0.936
#                    bus        541        784      0.947      0.927       0.96      0.936
#                  truck        884       2396       0.96      0.972      0.981      0.957
# Speed: 0.1ms preprocess, 6.0ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import shutil
shutil.copy('/kaggle/working/runs/detect/train/weights/best.pt', '/kaggle/working/day_m.pt')

from IPython.display import FileLink
FileLink(r'day_m.pt')
# Out:
# /kaggle/working/day_m.pt
