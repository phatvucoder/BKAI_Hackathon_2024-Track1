# %%
# !pip install -q git+https://github.com/phatvucoder/pdatakit.git
# !pip -q install gdown
# !sudo apt-get update & sudo apt-get install unzip
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://packages.cloud.google.com/apt gcsfuse-focal InRelease [1227 B]
# Get:4 https://packages.cloud.google.com/apt cloud-sdk InRelease [1618 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://packages.cloud.google.com/apt google-fast-socket InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1581 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://packages.cloud.google.com/apt gcsfuse-focal/main amd64 Packages [28.6 kB]
# Get:10 https://packages.cloud.google.com/apt cloud-sdk/main all Packages [1582 kB]
# Get:11 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [3428 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1172 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3318 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2732 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [45.2 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2449 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1223 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1512 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3408 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [52.2 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [33.7 kB]
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# Fetched 21.4 MB in 2s (11.5 MB/s)
# 0 upgraded, 0 newly installed, 0 to remove and 68 not upgraded.

# %%
# !gdown 17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP
# !unzip -q obj_mbkgr -d dataset
# !rm -rf /kaggle/working/dataset/__MACOSX
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP
# From (redirected): https://drive.google.com/uc?id=17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP&confirm=t&uuid=9cd88320-61c5-4950-bc5d-cd49d042f121
# To: /kaggle/working/obj_mbkgr.zip
# 100%|██████████████████████████████████████| 1.60G/1.60G [00:20<00:00, 76.3MB/s]

# %%
from pdatakit.pod.data_processor import DataProcessor
from pdatakit.pod.data_formatter import FormatType
import shutil

# %%
# shutil.copytree('/kaggle/input/bkai2024', '/kaggle/working/bkai2024')

# %%
processor = DataProcessor(
    data_root='./dataset/nighttime',
    image_extension='jpg',
    label_extension='txt',
    train_size=0.7,
    val_size=0.2,
    test_size=0.1,
    random_state=42
)

# %%
for i in range(4, 8):
    processor.process_labels(i, i-4)
# Out:
# Replacing '4' with '0' in label files...
# Label replacement completed. Processed 4629 files, modified 3867 files.
# Replacing '5' with '1' in label files...
# Label replacement completed. Processed 4629 files, modified 2683 files.
# Replacing '6' with '2' in label files...
# Label replacement completed. Processed 4629 files, modified 1617 files.
# Replacing '7' with '3' in label files...
# Label replacement completed. Processed 4629 files, modified 1849 files.

# %%
processor.split_data()
# Out:
# Data splitting completed.
# Training samples: 3232
# Validation samples: 923
# Testing samples: 474

# %%
processor.visualize_distributions()

# %%
class_mapping = {
    0: 'motorbike',
    1: 'car',
    2: 'bus',
    3: 'truck'
}

# Format the data into YOLO New format and save to 'formatted_data' directory
processor.format_data(
    output_dir='./yolo_data',
    format_type=FormatType.YOLO_NEW,
    class_mapping=class_mapping
)
# Out:
# Creating YOLO New format...
# Created data.yaml at yolo_data/data.yaml
# YOLO New format created successfully.
# Data formatted into yolo_new format and saved to ./yolo_data.

# %%
processor.summary()
# Out:
# ===== Data Manager Summary =====
# Data Root: ./dataset/nighttime
# Image Extension: jpg
# Label Extension: txt
# Total Images: 4629
# Total Labels: 4629
# Training Samples: 3232
# Validation Samples: 923
# Testing Samples: 474
# Class Distribution in Training Set:
#   0: 11206
#   1: 6061
#   2: 1732
#   3: 1962
# Class Distribution in Validation Set:
#   0: 2987
#   1: 1703
#   2: 472
#   3: 567
# Class Distribution in Testing Set:
#   0: 1664
#   1: 790
#   2: 258
#   3: 294
# =================================

# %%
import numpy as np

class_distribution = processor.splitter.get_class_distribution()
total_samples_per_class = np.sum(class_distribution, axis=0)
total_samples = np.sum(total_samples_per_class)
class_weights = total_samples / total_samples_per_class
class_weights
# Out:
# array([ 1.87273759,  3.47159224, 12.06173842, 10.5193057 ])

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
# !yolo train data=/kaggle/working/yolo_data/data.yaml model=yolo11m.pt lr0=0.0001 epochs=100 batch=32 device=0,1 cache=ram
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt'...
# 100%|███████████████████████████████████████| 38.8M/38.8M [00:00<00:00, 235MB/s]
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11m.pt, data=/kaggle/working/yolo_data/data.yaml, epochs=100, time=None, patience=100, batch=32, imgsz=640, save=True, save_period=-1, cache=ram, device=(0, 1), workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.0001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1414108  ultralytics.nn.modules.head.Detect           [4, [256, 512, 512]]
# YOLO11m summary: 409 layers, 20,056,092 parameters, 20,056,076 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# DDP: debug command /opt/conda/bin/python3.10 -m torch.distributed.run --nproc_per_node 2 --master_port 41253 /root/.config/Ultralytics/DDP/_temp_3ew780pc139380824091536.py
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/yolo_data/train/labels.cache... 3232 images, 0 b
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (2.1GB RAM): 100%|██████████| 3232/3232 [00:07<00:00, 421.
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/yolo_data/val/labels.cache... 923 images, 0 backgr
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.6GB RAM): 100%|██████████| 923/923 [00:04<00:00, 228.53it
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      8.75G     0.6663     0.9193     0.8527        385        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.864      0.835      0.874      0.772
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      8.72G     0.5114     0.3984     0.8096        245        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.902       0.91      0.946      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      8.69G     0.4914      0.366      0.805        293        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.92      0.911      0.941      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      8.68G     0.4724     0.3514     0.8027        320        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.92      0.905      0.948      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      8.66G     0.4527     0.3342     0.7985        248        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.926      0.906      0.952      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      8.72G       0.43     0.3133     0.7966        309        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.935      0.902      0.952       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      8.63G     0.4144     0.2995     0.7941        341        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.936      0.927      0.956      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      8.67G     0.4126      0.301     0.7948        286        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.948      0.909       0.96       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      8.66G     0.4016     0.2903     0.7927        331        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.931      0.923      0.958      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      8.81G      0.392     0.2823     0.7903        294        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.974       0.88      0.957      0.904
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100       8.7G     0.3783     0.2744      0.788        392        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.944      0.915      0.962       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      8.67G     0.3755     0.2659     0.7872        332        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.948      0.938       0.97      0.917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      8.63G     0.3686      0.264     0.7874        282        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.944      0.941      0.966      0.909
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      8.75G     0.3554     0.2528     0.7847        202        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.974      0.938      0.972      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      8.71G     0.3594     0.2565     0.7874        208        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.938      0.941      0.972      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      8.76G     0.3513     0.2503     0.7875        227        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.96      0.941      0.974      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      8.63G     0.3466     0.2481      0.783        236        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.938      0.935      0.973      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100       8.7G     0.3471     0.2469     0.7838        298        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.947      0.945      0.975      0.932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      8.67G     0.3389     0.2419     0.7821        332        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.97      0.947      0.976      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      8.66G      0.331     0.2393     0.7835        306        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.966      0.953      0.974      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      8.68G       0.33      0.234     0.7849        249        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.96      0.958       0.98      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100       8.7G     0.3247     0.2327     0.7834        282        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.954       0.94      0.976       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      8.71G     0.3213     0.2284     0.7809        254        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.961      0.958      0.979      0.938
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      8.73G     0.3232     0.2286     0.7812        290        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.97       0.95      0.977      0.934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      8.69G     0.3152     0.2246     0.7798        343        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.956      0.962      0.976      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      8.69G     0.3091     0.2205     0.7796        296        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.961      0.951      0.978      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      8.65G     0.3171     0.2258      0.782        281        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.966      0.952      0.975      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      8.71G     0.3159     0.2238     0.7813        242        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.968       0.95      0.977      0.935
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      8.63G     0.3104     0.2215     0.7791        268        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.965      0.958      0.979      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      8.67G     0.3054     0.2167     0.7791        284        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.97      0.962      0.981      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      8.69G     0.3013     0.2109     0.7794        344        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.969      0.961       0.98      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      8.67G     0.2996     0.2113     0.7791        201        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.975      0.962      0.983      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      8.69G     0.2982     0.2125     0.7784        262        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.972      0.955      0.978      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      8.71G     0.2955     0.2109     0.7792        218        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.965       0.96      0.983      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100       8.7G     0.2968       0.21     0.7808        296        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.97       0.96      0.982      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      8.72G     0.2928     0.2087     0.7784        268        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.961      0.982      0.947
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      8.63G     0.2876     0.2054     0.7779        252        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.967      0.961      0.981      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100       8.7G     0.2877     0.2034     0.7765        280        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.964      0.982      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      8.65G     0.2845     0.2026     0.7768        247        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.97      0.963      0.982      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      8.69G     0.2827     0.1992     0.7771        237        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.964      0.985      0.951
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      8.68G     0.2819     0.1971     0.7779        282        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.973      0.963      0.981      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      8.69G       0.28     0.1983      0.777        363        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.967      0.966      0.984      0.953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      8.65G     0.2833     0.1982     0.7773        266        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.97      0.959      0.983      0.951
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      8.72G     0.2738     0.1953     0.7787        246        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.972      0.955      0.982      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      8.63G     0.2767     0.1943     0.7778        291        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.971      0.965      0.981       0.95
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      8.72G     0.2727     0.1923     0.7764        213        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.967      0.984      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      8.69G     0.2733     0.1948     0.7757        220        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.974       0.96      0.983      0.951
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100       8.7G     0.2701     0.1937     0.7773        287        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.978      0.962      0.985      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      8.63G     0.2673     0.1912     0.7778        292        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.962      0.983      0.951
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      8.67G     0.2663     0.1884     0.7756        235        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.979      0.967      0.985      0.954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      8.66G     0.2644      0.185      0.777        318        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.977      0.964      0.981      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      8.74G      0.263     0.1861     0.7764        199        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.981      0.966      0.982      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      8.64G     0.2544     0.1804     0.7748        363        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.978      0.965      0.985      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      8.69G     0.2592     0.1828     0.7741        292        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.975      0.969      0.986      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      8.68G      0.261     0.1833     0.7742        286        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.971      0.968      0.984      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      8.72G     0.2523     0.1782      0.777        298        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.97      0.965      0.985      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      8.72G     0.2513     0.1787     0.7736        295        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.978      0.971      0.985      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      8.67G     0.2545     0.1799     0.7747        322        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.975       0.97      0.984      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      8.66G     0.2541     0.1775     0.7762        271        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.98      0.964      0.985      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      8.68G     0.2464     0.1726     0.7763        227        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.98      0.975      0.986      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      8.63G      0.243     0.1715     0.7743        334        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.982      0.971      0.985      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      8.73G     0.2439     0.1728      0.774        275        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.977       0.97      0.985      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      8.63G     0.2438     0.1701     0.7727        213        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.973      0.968      0.984      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100       8.7G     0.2422     0.1712     0.7745        355        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.981      0.968      0.986       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      8.71G     0.2383     0.1704     0.7743        271        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.977      0.973      0.986      0.959
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      8.75G     0.2391     0.1685     0.7727        231        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.975      0.972      0.985      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      8.63G     0.2384      0.167     0.7724        292        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.977      0.971      0.985      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      8.75G     0.2336      0.164      0.772        282        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.985      0.967      0.986      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      8.71G     0.2349     0.1652     0.7734        295        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.975      0.971      0.985      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      8.71G     0.2351     0.1665     0.7731        260        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.979      0.969      0.986       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      8.63G     0.2288     0.1621     0.7725        231        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.983       0.97      0.986      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      8.72G     0.2296     0.1624     0.7717        247        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.981      0.968      0.987      0.961
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      8.69G     0.2307     0.1607     0.7726        249        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.986      0.969      0.987      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      8.66G     0.2271      0.158     0.7714        365        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.984      0.974      0.988      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      8.67G     0.2252     0.1574     0.7721        270        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.979      0.974      0.986      0.961
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      8.68G     0.2288     0.1584     0.7716        256        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.984       0.97      0.985       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      8.71G     0.2243     0.1562      0.771        318        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.981      0.974      0.988      0.963
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      8.71G     0.2215     0.1547     0.7709        314        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.979      0.969      0.988      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      8.69G     0.2188     0.1527     0.7711        288        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.986      0.972      0.987      0.963
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      8.68G     0.2178     0.1528     0.7733        289        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.985      0.972      0.989      0.964
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      8.68G     0.2152     0.1493     0.7722        324        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.982      0.973      0.987      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      8.79G     0.2208      0.153     0.7703        265        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.986      0.974      0.986      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      8.67G     0.2169       0.15     0.7692        288        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.973      0.987      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100       8.7G     0.2139     0.1478     0.7707        217        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.986      0.967      0.988      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      8.64G     0.2109     0.1467     0.7723        212        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.981      0.973      0.987      0.963
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      8.67G     0.2137     0.1475     0.7702        288        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.977      0.988      0.963
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      8.71G     0.2118     0.1468     0.7714        239        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.98      0.975      0.988      0.964
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100       8.7G     0.2117     0.1464      0.773        219        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.979       0.98      0.989      0.964
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      8.64G     0.2088     0.1429     0.7703        210        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.983      0.973      0.989      0.965
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      8.73G     0.2038     0.1428     0.7686        271        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.985      0.971      0.989      0.964
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      8.82G     0.3143     0.1997     0.7792        115        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.978      0.975      0.987      0.963
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      8.85G     0.3086     0.1949     0.7765        114        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.988      0.972      0.989      0.965
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      8.78G     0.3074     0.1896     0.7787         90        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.986      0.976      0.989      0.966
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      8.71G     0.3016     0.1883     0.7732        118        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.986      0.973      0.989      0.967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      8.81G     0.2941     0.1801      0.776        100        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.981      0.978      0.989      0.966
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      8.86G     0.2967     0.1815     0.7734        122        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.98       0.98      0.989      0.967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      8.78G     0.2909     0.1762     0.7743         96        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.982       0.98      0.989      0.967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      8.84G     0.2896     0.1742      0.775        164        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.985      0.976      0.989      0.967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      8.78G     0.2854      0.173     0.7742        107        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.985      0.978      0.989      0.968
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      8.84G      0.284     0.1711     0.7747         91        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.986      0.974      0.989      0.968
#
# 100 epochs completed in 2.194 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 40.5MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 40.5MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 303 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.984      0.979      0.989      0.968
#              motorbike        773       2987      0.997      0.985      0.994      0.942
#                    car        536       1703      0.986      0.994      0.992      0.974
#                    bus        323        472       0.98      0.949      0.981      0.974
#                  truck        370        567      0.974      0.986      0.989      0.982
# Speed: 0.1ms preprocess, 6.8ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import shutil
shutil.copy('/kaggle/working/runs/detect/train/weights/best.pt', '/kaggle/working/night_m.pt')

from IPython.display import FileLink
FileLink(r'night_m.pt')
# Out:
# /kaggle/working/night.pt
