# %%
# !pip install -q git+https://github.com/phatvucoder/pdatakit.git
# !pip -q install gdown
# !sudo apt-get update & sudo apt-get install unzip
# Out:
# Get:1 https://packages.cloud.google.com/apt gcsfuse-focal InRelease [1227 B]
# Get:2 https://packages.cloud.google.com/apt cloud-sdk InRelease [1618 B]
# Hit:3 https://packages.cloud.google.com/apt google-fast-socket InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1581 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://packages.cloud.google.com/apt gcsfuse-focal/main amd64 Packages [28.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://packages.cloud.google.com/apt cloud-sdk/main all Packages [1582 kB]
# Get:10 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [3428 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1172 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1223 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [52.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3413 kB]
# Reading package lists... DonekB 0%] [13 Packages 165 kB/1223 kB 13%]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3318 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2734 kB]
# Building dependency tree... DonePackages 44.9 kB/2734 kB 2%] [16 Packages 1310
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1512 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2449 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [33.7 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [45.2 kB]
# 97% [17 Packages store 0 B]                                  0 upgraded, 0 newly installed, 0 to remove and 68 not upgraded.

# %%
# !gdown 17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP
# !unzip -q obj_mbkgr -d dataset
# !rm -rf /kaggle/working/dataset/__MACOSX
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP
# From (redirected): https://drive.google.com/uc?id=17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP&confirm=t&uuid=0d8a6131-4c25-4457-b175-2c7c0913a499
# To: /kaggle/working/obj_mbkgr.zip
# 100%|██████████████████████████████████████| 1.60G/1.60G [00:20<00:00, 78.0MB/s]

# %%
from pdatakit.pod.data_processor import DataProcessor
from pdatakit.pod.data_formatter import FormatType
import shutil

# %%
# shutil.copytree('/kaggle/input/bkai2024', '/kaggle/working/bkai2024')

# %%
processor = DataProcessor(
    data_root='./dataset/daytime',
    image_extension='jpg',
    label_extension='txt',
    train_size=0.7,
    val_size=0.2,
    test_size=0.1,
    random_state=42
)

# %%
for i in range(4, 8):
    processor.process_labels(i, i-4)
# Out:
# Replacing '4' with '0' in label files...
# Label replacement completed. Processed 6891 files, modified 0 files.
# Replacing '5' with '1' in label files...
# Label replacement completed. Processed 6891 files, modified 0 files.
# Replacing '6' with '2' in label files...
# Label replacement completed. Processed 6891 files, modified 0 files.
# Replacing '7' with '3' in label files...
# Label replacement completed. Processed 6891 files, modified 0 files.

# %%
processor.split_data()
# Out:
# Data splitting completed.
# Training samples: 4831
# Validation samples: 1388
# Testing samples: 672

# %%
processor.visualize_distributions()

# %%
class_mapping = {
    0: 'motorbike',
    1: 'car',
    2: 'bus',
    3: 'truck'
}

# Format the data into YOLO New format and save to 'formatted_data' directory
processor.format_data(
    output_dir='./yolo_data',
    format_type=FormatType.YOLO_NEW,
    class_mapping=class_mapping
)
# Out:
# Creating YOLO New format...
# Created data.yaml at yolo_data/data.yaml
# YOLO New format created successfully.
# Data formatted into yolo_new format and saved to ./yolo_data.

# %%
processor.summary()
# Out:
# ===== Data Manager Summary =====
# Data Root: ./dataset/daytime
# Image Extension: jpg
# Label Extension: txt
# Total Images: 6891
# Total Labels: 6891
# Training Samples: 4831
# Validation Samples: 1388
# Testing Samples: 672
# Class Distribution in Training Set:
#   0: 45111
#   1: 12148
#   2: 2855
#   3: 8299
# Class Distribution in Validation Set:
#   0: 13941
#   1: 3697
#   2: 784
#   3: 2396
# Class Distribution in Testing Set:
#   0: 6554
#   1: 1709
#   2: 396
#   3: 1178
# =================================

# %%
import numpy as np

class_distribution = processor.splitter.get_class_distribution()
total_samples_per_class = np.sum(class_distribution, axis=0)
total_samples = np.sum(total_samples_per_class)
class_weights = total_samples / total_samples_per_class
class_weights
# Out:
# array([ 1.51004481,  5.64361399, 24.55216853,  8.34397372])

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.35 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
# !yolo train data=/kaggle/working/yolo_data/data.yaml model=yolo11m.pt lr0=0.0001 epochs=100 batch=32 device=0,1 cache=ram
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt'...
# 100%|███████████████████████████████████████| 38.8M/38.8M [00:00<00:00, 159MB/s]
# Ultralytics 8.3.35 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11m.pt, data=/kaggle/working/yolo_data/data.yaml, epochs=100, time=None, patience=100, batch=32, imgsz=640, save=True, save_period=-1, cache=ram, device=(0, 1), workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.0001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 10.8MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1414108  ultralytics.nn.modules.head.Detect           [4, [256, 512, 512]]
# YOLO11m summary: 409 layers, 20,056,092 parameters, 20,056,076 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# DDP: debug command /opt/conda/bin/python3.10 -m torch.distributed.run --nproc_per_node 2 --master_port 35323 /root/.config/Ultralytics/DDP/_temp_7qhktrwd137714103282240.py
# Ultralytics 8.3.35 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 73.3MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/working/yolo_data/train/labels... 4831 images, 0 backgro
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_01_00317.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_01_00857.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_01_00961.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00316.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00565.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00579.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00951.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00022.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00110.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00328.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00346.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00355.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00374.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00491.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00514.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00536.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00633.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00709.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00881.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00915.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00947.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_06_00803.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_10_00135.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_10_00136.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/yolo_data/train/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (3.1GB RAM): 100%|██████████| 4831/4831 [00:10<00:00, 453.
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/yolo_data/val/labels... 1388 images, 0 backgrounds
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00014.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00016.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00018.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00257.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00279.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00310.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00716.jpg: 1 duplicate labels removed
# val: New cache created: /kaggle/working/yolo_data/val/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.9GB RAM): 100%|██████████| 1388/1388 [00:05<00:00, 261.21
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      9.19G      0.691     0.6815     0.8517        842        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.821       0.78      0.813      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      9.12G     0.5221     0.3602     0.8109        755        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.921      0.889      0.934      0.819
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      9.12G     0.4866     0.3373     0.8037        748        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.923      0.863      0.934      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      9.04G     0.4697     0.3222     0.8011        685        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.907      0.875      0.915      0.815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      8.93G     0.4517     0.3074     0.7993        847        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.923      0.898      0.939      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100       9.1G     0.4221     0.2858     0.7943        595        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.933      0.912      0.944      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      8.92G     0.4076     0.2759     0.7924        940        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.928      0.906      0.947       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100       8.8G     0.4081     0.2768     0.7923        779        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.932      0.912      0.951      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      8.93G     0.3919     0.2633     0.7898        723        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.936       0.92      0.956      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      8.99G     0.3829     0.2598     0.7896        804        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.943      0.932      0.961      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      9.11G     0.3716     0.2517     0.7879        719        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.935      0.931      0.959      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100       9.1G     0.3636     0.2475     0.7868        822        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.93      0.905      0.942      0.863
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      9.17G     0.3581     0.2443      0.786        914        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.94      0.928       0.96      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      9.08G      0.351     0.2404     0.7854        626        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.945      0.921      0.953      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      9.04G     0.3466     0.2375     0.7857        583        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.947      0.931      0.965      0.885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      8.93G     0.3438     0.2333     0.7849        785        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.957      0.937      0.968      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      8.89G     0.3356     0.2296     0.7842        924        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.944      0.941      0.967      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      9.14G     0.3326     0.2275     0.7833        860        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.957      0.936      0.967      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      9.11G     0.3245     0.2214     0.7816        757        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.943      0.927      0.963      0.894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      8.92G     0.3208     0.2197     0.7823        777        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.951      0.939      0.963      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      8.92G     0.3194     0.2191     0.7804        545        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.956      0.948       0.97      0.904
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      9.07G     0.3128     0.2146     0.7805        736        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.948      0.941      0.966      0.896
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      9.16G     0.3122     0.2128     0.7809        682        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.954      0.936      0.971      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      9.13G      0.305     0.2098     0.7807        750        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.955       0.94       0.97      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      9.13G     0.3021     0.2081     0.7803        824        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.953      0.941       0.97      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      9.17G     0.3021     0.2076     0.7799        678        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.955      0.944      0.969      0.904
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      8.92G     0.2944     0.2017     0.7786        856        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.953      0.946      0.968      0.906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      9.03G     0.2945     0.2035     0.7788        587        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.956      0.944      0.972      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      9.09G     0.2947     0.2038     0.7784        768        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.938      0.945      0.971      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      9.11G     0.2855      0.198     0.7786        595        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.956      0.948      0.973      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      9.12G     0.2883     0.1988      0.779        600        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.953      0.945      0.971      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      9.16G     0.2837      0.196     0.7781        820        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.957      0.937       0.97      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100       9.1G      0.277     0.1933     0.7773        676        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.956      0.949      0.973      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      9.35G     0.2791     0.1927      0.778        708        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.957      0.942      0.972      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      8.91G     0.2748     0.1914     0.7773        605        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.952       0.94      0.972      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      9.19G     0.2699     0.1867     0.7771        728        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.959      0.935      0.973      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      9.08G     0.2673     0.1865     0.7773        717        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.96      0.951      0.974      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      9.13G     0.2647     0.1828     0.7768        839        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.96      0.952      0.975      0.917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      9.04G     0.2653     0.1846     0.7766        633        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.96      0.952      0.976      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      8.95G     0.2659     0.1854     0.7761        548        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.959      0.953      0.974      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      9.11G     0.2637     0.1825     0.7762        529        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.953      0.941      0.972      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100       9.2G     0.2648     0.1828      0.775        898        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.963       0.95      0.977      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      8.91G       0.26      0.181     0.7754        855        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.959      0.952      0.974      0.917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      9.42G      0.255     0.1779     0.7748        835        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.957      0.948      0.973      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      9.06G     0.2539     0.1775     0.7748        592        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.965      0.951      0.973      0.917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      9.09G     0.2521     0.1751     0.7745        726        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.962      0.958      0.974      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      8.94G     0.2499     0.1736     0.7749        713        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.946      0.974      0.917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      8.89G     0.2485      0.174     0.7754        985        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.959      0.955      0.975       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100       9.3G     0.2506     0.1737     0.7753        755        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.963      0.956      0.977      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100       9.1G     0.2477     0.1729     0.7742        566        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.961      0.951      0.976       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100       8.9G     0.2496     0.1729     0.7748        676        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.956      0.958      0.975      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      9.13G     0.2403      0.169     0.7735        734        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.967      0.955      0.977      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      9.16G     0.2413     0.1683     0.7746        750        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.967      0.954      0.977      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      9.18G     0.2391     0.1667     0.7738        773        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.96      0.962      0.978      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      9.08G      0.243     0.1703     0.7738        768        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.96      0.957      0.977      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100         9G     0.2406     0.1665     0.7733        737        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.961      0.958      0.976      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      9.14G     0.2387     0.1662     0.7738        665        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.965      0.955      0.976      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      9.12G     0.2362     0.1631     0.7725        718        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.961      0.957      0.978      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      8.92G     0.2327     0.1613     0.7731        766        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.963      0.957      0.978      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      9.21G     0.2311     0.1603      0.773        603        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.959      0.958      0.977      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      8.92G     0.2313     0.1602     0.7721        768        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.951      0.977      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      8.89G     0.2295     0.1586     0.7718        730        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.963      0.961      0.979      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      9.06G     0.2265     0.1574     0.7734        718        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.961      0.977      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      9.09G     0.2287     0.1588     0.7728        782        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.964       0.96      0.977      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      8.89G     0.2244     0.1561     0.7717        703        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.965      0.959      0.977      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      9.11G     0.2217     0.1536     0.7712        685        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.969      0.955      0.978      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      8.89G     0.2242     0.1546     0.7715        816        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.964      0.961      0.977      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      8.94G     0.2202     0.1527     0.7717        735        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.964      0.963      0.978      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100       8.9G     0.2254     0.1547     0.7726        951        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.961      0.978      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      8.98G     0.2215      0.153      0.772        707        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.969      0.951      0.977      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100       8.9G     0.2236     0.1539     0.7723        910        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.962      0.963      0.977      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      9.06G     0.2172     0.1497     0.7708        706        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.965      0.959      0.978      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      9.15G     0.2156     0.1478     0.7716        804        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.964      0.979       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      8.98G     0.2174     0.1491     0.7716        816        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.962      0.979       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      9.06G     0.2153     0.1476     0.7718        665        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.962      0.979      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      8.96G     0.2115     0.1463     0.7714        802        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.965      0.967      0.979       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      9.09G     0.2109     0.1458     0.7716        560        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.964      0.978      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      9.23G     0.2099     0.1441     0.7705       1121        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.965      0.978      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      8.91G      0.203     0.1406     0.7701        679        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.966      0.979       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      9.18G      0.211     0.1435     0.7704        888        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.963      0.964      0.979       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      9.08G     0.2068     0.1413     0.7706        731        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968       0.96      0.979       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      9.11G     0.2064     0.1412     0.7704        793        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.961       0.98      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100       9.1G      0.205     0.1401     0.7706        801        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.964      0.961      0.979       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      9.03G     0.2048     0.1394     0.7709        758        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.964      0.966      0.979      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      9.11G     0.2033     0.1376     0.7703        797        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.97       0.96      0.979      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      9.18G     0.2003     0.1365     0.7706        695        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.962      0.964      0.979      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      9.18G     0.2003     0.1365     0.7705        803        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.962      0.968      0.979      0.932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      9.18G     0.1987     0.1344     0.7703        896        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.967      0.966      0.979      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      9.15G     0.1996     0.1351     0.7702        596        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.963       0.98      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      9.13G     0.1955     0.1327     0.7704        490        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.965      0.968      0.979      0.932
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100       8.7G      0.395     0.2324     0.7898        235        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.971      0.966       0.98      0.934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      8.67G     0.3794     0.2226     0.7877        233        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.972      0.963      0.981      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      8.72G     0.3723     0.2189     0.7833        243        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.97      0.965       0.98      0.935
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      8.69G     0.3664     0.2158     0.7829        163        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.966      0.968       0.98      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100       8.7G     0.3636     0.2108     0.7831        182        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.968      0.969       0.98      0.938
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      8.64G     0.3615     0.2078     0.7824        229        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.969      0.964       0.98      0.938
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      8.76G      0.356     0.2048     0.7816        190        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.971      0.968      0.979      0.938
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      8.74G     0.3543     0.2061     0.7819        291        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.972      0.966       0.98      0.939
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      8.73G     0.3529     0.2008       0.78        207        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.971      0.967       0.98      0.939
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      8.67G     0.3477     0.1982     0.7818        252        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811       0.97      0.968       0.98      0.939
#
# 100 epochs completed in 3.430 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 40.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 40.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.35 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 303 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1388      20811      0.972      0.966       0.98      0.939
#              motorbike       1298      13936      0.996      0.987      0.994      0.919
#                    car       1051       3695      0.982      0.977      0.988      0.942
#                    bus        541        784      0.946       0.93      0.957      0.935
#                  truck        884       2396      0.963       0.97      0.983      0.962
# Speed: 0.1ms preprocess, 6.9ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import shutil
shutil.copy('/kaggle/working/runs/detect/train/weights/best.pt', '/kaggle/working/day_m.pt')

from IPython.display import FileLink
FileLink(r'day_m.pt')
# Out:
# /kaggle/working/day.pt
