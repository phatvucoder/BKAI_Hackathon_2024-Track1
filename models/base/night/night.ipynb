# %%
# !pip install -q git+https://github.com/phatvucoder/pdatakit.git
# !pip -q install gdown
# !sudo apt-get update & sudo apt-get install unzip
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://packages.cloud.google.com/apt gcsfuse-focal InRelease [1227 B]
# Get:4 https://packages.cloud.google.com/apt cloud-sdk InRelease [1618 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://packages.cloud.google.com/apt google-fast-socket InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1581 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://packages.cloud.google.com/apt gcsfuse-focal/main amd64 Packages [28.6 kB]
# Get:10 https://packages.cloud.google.com/apt cloud-sdk/main all Packages [1582 kB]
# Get:11 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [3428 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1172 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3318 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2732 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [45.2 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2449 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1223 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1512 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3408 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [52.2 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [33.7 kB]
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# Fetched 21.4 MB in 2s (11.5 MB/s)
# 0 upgraded, 0 newly installed, 0 to remove and 68 not upgraded.

# %%
# !gdown 17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP
# !unzip -q obj_mbkgr -d dataset
# !rm -rf /kaggle/working/dataset/__MACOSX
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP
# From (redirected): https://drive.google.com/uc?id=17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP&confirm=t&uuid=9cd88320-61c5-4950-bc5d-cd49d042f121
# To: /kaggle/working/obj_mbkgr.zip
# 100%|██████████████████████████████████████| 1.60G/1.60G [00:20<00:00, 76.3MB/s]

# %%
from pdatakit.pod.data_processor import DataProcessor
from pdatakit.pod.data_formatter import FormatType
import shutil

# %%
# shutil.copytree('/kaggle/input/bkai2024', '/kaggle/working/bkai2024')

# %%
processor = DataProcessor(
    data_root='./dataset/nighttime',
    image_extension='jpg',
    label_extension='txt',
    train_size=0.7,
    val_size=0.2,
    test_size=0.1,
    random_state=42
)

# %%
for i in range(4, 8):
    processor.process_labels(i, i-4)
# Out:
# Replacing '4' with '0' in label files...
# Label replacement completed. Processed 4629 files, modified 3867 files.
# Replacing '5' with '1' in label files...
# Label replacement completed. Processed 4629 files, modified 2683 files.
# Replacing '6' with '2' in label files...
# Label replacement completed. Processed 4629 files, modified 1617 files.
# Replacing '7' with '3' in label files...
# Label replacement completed. Processed 4629 files, modified 1849 files.

# %%
processor.split_data()
# Out:
# Data splitting completed.
# Training samples: 3232
# Validation samples: 923
# Testing samples: 474

# %%
processor.visualize_distributions()

# %%
class_mapping = {
    0: 'motorbike',
    1: 'car',
    2: 'bus',
    3: 'truck'
}

# Format the data into YOLO New format and save to 'formatted_data' directory
processor.format_data(
    output_dir='./yolo_data',
    format_type=FormatType.YOLO_NEW,
    class_mapping=class_mapping
)
# Out:
# Creating YOLO New format...
# Created data.yaml at yolo_data/data.yaml
# YOLO New format created successfully.
# Data formatted into yolo_new format and saved to ./yolo_data.

# %%
processor.summary()
# Out:
# ===== Data Manager Summary =====
# Data Root: ./dataset/nighttime
# Image Extension: jpg
# Label Extension: txt
# Total Images: 4629
# Total Labels: 4629
# Training Samples: 3232
# Validation Samples: 923
# Testing Samples: 474
# Class Distribution in Training Set:
#   0: 11206
#   1: 6061
#   2: 1732
#   3: 1962
# Class Distribution in Validation Set:
#   0: 2987
#   1: 1703
#   2: 472
#   3: 567
# Class Distribution in Testing Set:
#   0: 1664
#   1: 790
#   2: 258
#   3: 294
# =================================

# %%
import numpy as np

class_distribution = processor.splitter.get_class_distribution()
total_samples_per_class = np.sum(class_distribution, axis=0)
total_samples = np.sum(total_samples_per_class)
class_weights = total_samples / total_samples_per_class
class_weights
# Out:
# array([ 1.87273759,  3.47159224, 12.06173842, 10.5193057 ])

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
# !yolo train data=/kaggle/working/yolo_data/data.yaml model=yolo11n.pt lr0=0.0001 epochs=100 batch=32 device=0,1 cache=ram
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 76.5MB/s]
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11n.pt, data=/kaggle/working/yolo_data/data.yaml, epochs=100, time=None, patience=100, batch=32, imgsz=640, save=True, save_period=-1, cache=ram, device=(0, 1), workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.0001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 15.7MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# DDP: debug command /opt/conda/bin/python3.10 -m torch.distributed.run --nproc_per_node 2 --master_port 48699 /root/.config/Ultralytics/DDP/_temp_965htf34137787208460864.py
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/yolo_data/train/labels... 3232 images, 0 backgro
# train: New cache created: /kaggle/working/yolo_data/train/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (2.1GB RAM): 100%|██████████| 3232/3232 [00:07<00:00, 442.
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/yolo_data/val/labels... 923 images, 0 backgrounds,
# val: New cache created: /kaggle/working/yolo_data/val/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.6GB RAM): 100%|██████████| 923/923 [00:03<00:00, 235.07it
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.81G      1.108       2.42     0.9294        394        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.687      0.608      0.671      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.72G     0.7754     0.7583     0.8479        266        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.73      0.814      0.819      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.79G     0.7182     0.6436     0.8369        288        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.801      0.801      0.849      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.09G     0.6763     0.5833     0.8285        308        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.886      0.811      0.906      0.759
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.75G      0.644     0.5303     0.8244        250        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.834      0.872      0.899      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.92G     0.6262     0.4894     0.8203        312        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.897      0.881      0.937      0.804
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      3.03G     0.6046     0.4571     0.8179        327        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.887      0.877      0.929      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.99G     0.5907     0.4424     0.8158        281        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.889      0.886      0.933      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.84G     0.5795     0.4246     0.8125        319        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.916      0.894      0.951      0.825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      3.16G     0.5756     0.4154      0.812        291        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.909      0.901      0.951       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.74G     0.5584     0.4016     0.8101        388        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.912      0.913      0.948      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.64G     0.5551     0.3883     0.8076        332        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.916        0.9      0.944      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.59G     0.5381     0.3785     0.8071        275        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.908      0.919       0.95       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.94G     0.5281     0.3694     0.8049        198        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.932      0.914      0.963      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.89G     0.5297     0.3662     0.8059        209        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.93      0.911      0.963      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.79G      0.519     0.3572     0.8064        219        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.944      0.908      0.967      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100       3.1G     0.5075     0.3497     0.8011        248        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.942      0.921      0.964      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.84G     0.5165     0.3507     0.8032        306        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.925       0.91       0.96      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.957      0.984      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      2.98G     0.3779     0.2556     0.7871        351        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.961       0.96      0.981      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100       2.9G     0.3734     0.2533     0.7865        262        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.968      0.956      0.981      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.74G     0.3776     0.2549     0.7868        224        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.962      0.954       0.98      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.84G     0.3731     0.2514     0.7854        294        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.969      0.959      0.981      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.79G     0.3711     0.2496     0.7858        280        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.972      0.956      0.981      0.906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.95G     0.3691     0.2478     0.7855        282        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.971      0.959      0.984      0.909
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.92G     0.3694     0.2502     0.7854        262        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.968       0.96      0.983       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      3.12G     0.3632      0.246     0.7854        219        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.973       0.96      0.984      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100       2.7G     0.3657     0.2467     0.7856        256        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.966      0.958       0.98      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.94G      0.365      0.245     0.7853        235        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.977      0.959      0.984      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.77G      0.362     0.2426     0.7838        366        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.961      0.984      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      3.07G     0.3605     0.2407     0.7866        277        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.968      0.962      0.984      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.97G     0.3619     0.2421     0.7851        260        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.975      0.956      0.983      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      2.85G     0.3568       0.24      0.784        312        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.973      0.959      0.983      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.88G     0.3556     0.2395     0.7837        318        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.973      0.962      0.987      0.916
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.67G     0.3549     0.2384     0.7848        278        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.968      0.965      0.985      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.85G     0.3496     0.2358     0.7848        289        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.973      0.958      0.984      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.94G      0.346     0.2325     0.7834        318        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.974      0.959      0.984      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100       2.8G     0.3576     0.2398     0.7834        258        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.973      0.963      0.986      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100       2.8G     0.3503     0.2357     0.7828        277        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.972      0.968      0.986      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.98G     0.3489      0.233     0.7848        209        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.975      0.963      0.986      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.61G     0.3479     0.2329     0.7856        221        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.965      0.985      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.99G      0.349      0.234     0.7829        287        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.966      0.986      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.65G     0.3438     0.2332     0.7831        238        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.973      0.969      0.986      0.916
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.91G     0.3476     0.2326     0.7851        213        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.968      0.986      0.916
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      3.06G     0.3457     0.2306     0.7834        211        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.978      0.966      0.985      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.88G     0.3369     0.2282     0.7825        280        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.978      0.966      0.984      0.915
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.44G     0.4991      0.308     0.8042        115        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.975      0.962      0.982      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.46G     0.4818      0.296     0.8007        114        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.973      0.964      0.983      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.46G     0.4781     0.2894     0.7998         90        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.976      0.965      0.984      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.43G     0.4761     0.2863     0.7968        118        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.974      0.972      0.986       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.46G     0.4606     0.2798     0.7971        100        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.978      0.968      0.985       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100       2.4G     0.4676     0.2789     0.7952        122        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.977      0.966      0.986      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.44G     0.4561     0.2755     0.7969         96        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.975       0.97      0.986      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.46G     0.4592     0.2778      0.797        164        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729       0.98      0.969      0.987      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.43G     0.4485     0.2714     0.7943        107        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.977       0.97      0.986      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100       2.4G     0.4528     0.2712     0.7963         91        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.979      0.969      0.986      0.924
#
# 100 epochs completed in 0.902 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 5.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        923       5729      0.979      0.969      0.986      0.924
#              motorbike        773       2987      0.993      0.974       0.99      0.864
#                    car        536       1703      0.983      0.981      0.991      0.936
#                    bus        323        472      0.971      0.941      0.977      0.944
#                  truck        370        567      0.969      0.982      0.988       0.95
# Speed: 0.1ms preprocess, 1.3ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import shutil
shutil.copy('/kaggle/working/runs/detect/train/weights/best.pt', '/kaggle/working/best.pt')

# %%
from IPython.display import FileLink
FileLink(r'best.pt')
# Out:
# /kaggle/working/best.pt
