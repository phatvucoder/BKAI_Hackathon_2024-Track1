# %%
# !pip install -q git+https://github.com/phatvucoder/pdatakit.git
# !pip -q install gdown
# !sudo apt-get update & sudo apt-get install unzip
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1581 B]
# Get:2 https://packages.cloud.google.com/apt gcsfuse-focal InRelease [1227 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1172 kB]
# Get:6 https://packages.cloud.google.com/apt cloud-sdk InRelease [1618 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://packages.cloud.google.com/apt google-fast-socket InRelease
# Get:9 https://packages.cloud.google.com/apt gcsfuse-focal/main amd64 Packages [28.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [3428 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3318 kB]
# Get:13 https://packages.cloud.google.com/apt cloud-sdk/main all Packages [1582 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [52.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1512 kB]
# Reading package lists... DonekB 0%] [12 Packages 502 kB/3318 kB 15%]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3408 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [45.2 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1223 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2449 kB]
# Building dependency tree... DonePackages 1023 kB/3408 kB 30%] [19 Packages 116
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2732 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [33.7 kB]
# 98% [19 Packages store 0 B]                                   0 upgraded, 0 newly installed, 0 to remove and 68 not upgraded.

# %%
# !gdown 17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP
# !unzip -q obj_mbkgr -d dataset
# !rm -rf /kaggle/working/dataset/__MACOSX
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP
# From (redirected): https://drive.google.com/uc?id=17Q1JYuL0pU4eeXPqDFzz6P5ohxGM-BnP&confirm=t&uuid=8bdcadaa-31f9-469e-8932-841d8dfe22b8
# To: /kaggle/working/obj_mbkgr.zip
# 100%|██████████████████████████████████████| 1.60G/1.60G [00:20<00:00, 76.7MB/s]

# %%
from pdatakit.pod.data_processor import DataProcessor
from pdatakit.pod.data_formatter import FormatType
import shutil

# %%
# shutil.copytree('/kaggle/input/bkai2024', '/kaggle/working/bkai2024')

# %%
processor = DataProcessor(
    data_root='./dataset',
    image_extension='jpg',
    label_extension='txt',
    train_size=0.7,
    val_size=0.2,
    test_size=0.1,
    random_state=42
)

# %%
for i in range(4, 8):
    processor.process_labels(i, i-4)
# Out:
# Replacing '4' with '0' in label files...
# Label replacement completed. Processed 11520 files, modified 3867 files.
# Replacing '5' with '1' in label files...
# Label replacement completed. Processed 11520 files, modified 2683 files.
# Replacing '6' with '2' in label files...
# Label replacement completed. Processed 11520 files, modified 1617 files.
# Replacing '7' with '3' in label files...
# Label replacement completed. Processed 11520 files, modified 1849 files.

# %%
processor.split_data()
# Out:
# Data splitting completed.
# Training samples: 8046
# Validation samples: 2319
# Testing samples: 1155

# %%
processor.visualize_distributions()

# %%
class_mapping = {
    0: 'motorbike',
    1: 'car',
    2: 'bus',
    3: 'truck'
}

# Format the data into YOLO New format and save to 'formatted_data' directory
processor.format_data(
    output_dir='./yolo_data',
    format_type=FormatType.YOLO_NEW,
    class_mapping=class_mapping
)
# Out:
# Creating YOLO New format...
# Created data.yaml at yolo_data/data.yaml
# YOLO New format created successfully.
# Data formatted into yolo_new format and saved to ./yolo_data.

# %%
processor.summary()
# Out:
# ===== Data Manager Summary =====
# Data Root: ./dataset
# Image Extension: jpg
# Label Extension: txt
# Total Images: 11520
# Total Labels: 11520
# Training Samples: 8046
# Validation Samples: 2319
# Testing Samples: 1155
# Class Distribution in Training Set:
#   0: 57988
#   1: 18288
#   2: 4564
#   3: 10216
# Class Distribution in Validation Set:
#   0: 15738
#   1: 5264
#   2: 1305
#   3: 3033
# Class Distribution in Testing Set:
#   0: 7737
#   1: 2556
#   2: 628
#   3: 1447
# =================================

# %%
import numpy as np

class_distribution = processor.splitter.get_class_distribution()
total_samples_per_class = np.sum(class_distribution, axis=0)
total_samples = np.sum(total_samples_per_class)
class_weights = total_samples / total_samples_per_class
class_weights
# Out:
# array([ 1.58064397,  4.93197487, 19.81899338,  8.76183996])

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
# !yolo train data=/kaggle/working/yolo_data/data.yaml model=yolo11m.pt lr0=0.0001 epochs=100 batch=32 device=0,1 cache=ram
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt'...
# 100%|███████████████████████████████████████| 38.8M/38.8M [00:00<00:00, 248MB/s]
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11m.pt, data=/kaggle/working/yolo_data/data.yaml, epochs=100, time=None, patience=100, batch=32, imgsz=640, save=True, save_period=-1, cache=ram, device=(0, 1), workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.0001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1414108  ultralytics.nn.modules.head.Detect           [4, [256, 512, 512]]
# YOLO11m summary: 409 layers, 20,056,092 parameters, 20,056,076 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# DDP: debug command /opt/conda/bin/python3.10 -m torch.distributed.run --nproc_per_node 2 --master_port 32933 /root/.config/Ultralytics/DDP/_temp_ql3jbg0f138983289744272.py
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/yolo_data/train/labels... 8046 images, 0 backgro
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_01_00317.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_01_00857.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_01_00961.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00565.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00579.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_02_00951.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00016.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00018.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00022.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00110.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00257.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00279.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00310.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00346.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00491.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00514.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00633.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00709.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00716.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00881.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00915.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_04_00947.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_06_00803.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_10_00135.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo_data/train/images/cam_10_00136.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/yolo_data/train/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (5.2GB RAM): 100%|██████████| 8046/8046 [00:18<00:00, 437.
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/yolo_data/val/labels... 2319 images, 0 backgrounds
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00014.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00328.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/yolo_data/val/images/cam_04_00355.jpg: 1 duplicate labels removed
# val: WARNING ⚠️
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.979      0.968      0.986      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      8.94G     0.1959     0.1366     0.7707        237        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.977      0.971      0.985      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      8.91G     0.1964     0.1367     0.7706        343        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.978      0.968      0.985      0.941
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      9.14G      0.192      0.134     0.7701        314        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.977      0.971      0.986      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      8.98G     0.1943     0.1346     0.7706        379        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.976      0.973      0.986      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      9.03G     0.1921     0.1326     0.7696        369        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.978      0.972      0.986      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      9.01G     0.1948      0.134     0.7705        289        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.978      0.972      0.986      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      9.14G     0.1894     0.1312     0.7704        126        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336       0.98      0.972      0.986      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      9.08G     0.1882       0.13     0.7705        264        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.981      0.969      0.986      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      9.04G     0.1907     0.1304     0.7702        180        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.978      0.973      0.986      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      8.99G     0.1858     0.1277     0.7701        250        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.977      0.972      0.986      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      8.97G     0.1855     0.1278     0.7694        313        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.978      0.971      0.986      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      9.05G     0.1837     0.1259     0.7698        362        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.977      0.972      0.986      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      9.14G     0.1855     0.1265     0.7695        266        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.979      0.971      0.985      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100       9.1G     0.1817     0.1236      0.769        394        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.979      0.972      0.985      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      9.11G     0.1809     0.1233     0.7689        337        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.978      0.972      0.985      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      8.99G     0.1804     0.1222     0.7694        441        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336       0.98      0.971      0.985      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      9.12G     0.1786     0.1209     0.7697        310        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.979      0.973      0.985      0.944
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      8.61G     0.3731     0.2211     0.7899         81        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.979      0.973      0.986      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      8.61G     0.3678     0.2155     0.7873         82        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336       0.98      0.973      0.986      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      8.58G     0.3647      0.208      0.787         59        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.979      0.975      0.986      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      8.63G     0.3612     0.2084     0.7861         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336       0.98      0.974      0.986      0.947
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      8.66G     0.3564     0.2044     0.7852         98        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.981      0.974      0.986      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      8.57G     0.3512     0.1972     0.7839        149        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.981      0.973      0.986      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      8.67G     0.3479     0.1958     0.7829         61        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.981      0.973      0.986      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      8.68G     0.3397     0.1912     0.7824         92        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.982      0.973      0.986      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      8.57G     0.3457     0.1925     0.7827         87        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.981      0.973      0.986      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      8.59G     0.3351     0.1873     0.7793         70        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.982      0.973      0.986      0.949
#
# 100 epochs completed in 5.111 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 40.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 40.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.34 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 303 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2319      25336      0.982      0.973      0.986      0.949
#              motorbike       2072      15736      0.995      0.987      0.994      0.921
#                    car       1588       5263      0.985      0.979      0.988      0.953
#                    bus        865       1304      0.971      0.955      0.977      0.961
#                  truck       1255       3033      0.976       0.97      0.985      0.963
# Speed: 0.1ms preprocess, 5.7ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import shutil
shutil.copy('/kaggle/working/runs/detect/train/weights/best.pt', '/kaggle/working/base_m.pt')

from IPython.display import FileLink
FileLink(r'base_m.pt')
# Out:
# /kaggle/working/base_m.pt
